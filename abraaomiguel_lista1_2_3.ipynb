# %% [markdown]
# <a href="https://colab.research.google.com/github/migueel-udf/TecnicasdedDesenvolvimento-de-Algoritmo_TecnicasdeProgama-ao/blob/main/abraaomiguel_lista1_2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nome: Abraão Miguel
# Turma: Engenharia de Software
# Disciplina: Tecnicas de Programação
# ![py.jpg](data:image/jpeg;base64,...)

# %%
print("Hello Word!")
# Out:
# Hello Word!

# %% [markdown]
# # 📘 Lista 1 – Exercícios

# %% [markdown]
# ## Exercício 1

# %%
print('Meu primeiro programa!!!')

# %% [markdown]
# ## Exercício 2

# %%
n=int(input('Digite um número: ')); print(n)

# %% [markdown]
# ## Exercício 3

# %%
n=int(input('Digite um número: ')); print(f'Foi informado o valor: {n}')

# %% [markdown]
# ## Exercício 4

# %%
a=int(input('A: ')); b=int(input('B: ')); print(f'Você informou os números {a} e {b}')

# %% [markdown]
# ## Exercício 5

# %%
x=float(input('Número real: ')); print(f'Você informou {x:.2f}')

# %% [markdown]
# ## Exercício 6

# %%
c=float(input('Celsius: ')); print('Fahrenheit =', c*1.8+32)

# %% [markdown]
# ## Exercício 7

# %%
n=int(input('Número: ')); x=float(input('Real: ')); print(f'Você informou {n} e {x:.2f}')

# %% [markdown]
# ## Exercício 8

# %%
l=input('Primeira letra: '); print(f'Você digitou {l}')

# %% [markdown]
# ## Exercício 9

# %%
cor=input('Cor preferida: '); print(f'Você gosta da cor {cor}')

# %% [markdown]
# ## Exercício 10

# %%
v=input('Verdura: '); f=input('Fruta: '); print(f'Você gosta de {v} e {f}')

# %% [markdown]
# ## Exercício 11

# %%
x=float(input('Número: ')); print('Número ->',x); print('Dobro ->',x*2)

# %% [markdown]
# ## Exercício 12

# %%
x=float(input('Número: ')); print('Quadrado=',x**2,'Cubo=',x**3)

# %% [markdown]
# ## Exercício 13

# %%
a=int(input('A: ')); b=int(input('B: ')); print(f'Soma = {a+b}')

# %% [markdown]
# ## Exercício 14

# %%
a=float(input('A: ')); b=float(input('B: ')); print(f'Produto = {a*b}')

# %% [markdown]
# ## Exercício 15

# %%
a=float(input('A: ')); b=float(input('B: ')); print(a+b, a-b, a*b, a/b)

# %% [markdown]
# ## Exercício 16

# %%
sal=float(input('Salário: ')); vend=float(input('Vendas: ')); com=float(input('Comissão %: ')); print(sal+vend*com/100)
# Out:
# Salário: 2
# Vendas: 3
# Comissão %: 2
# 2.06

# %% [markdown]
# # 📗 Lista 2 – Exercícios

# %% [markdown]
# ## Exercício 1

# %%
n=float(input('Número: ')); print('Maior que 10' if n>10 else 'Não é maior que 10')

# %% [markdown]
# ## Exercício 2

# %%
n=float(input('Número: ')); print('>=10' if n>=10 else '<10')

# %% [markdown]
# ## Exercício 3

# %%
n=float(input('Número: ')); print('Maior' if n>10 else ('Menor' if n<10 else 'Igual'))

# %% [markdown]
# ## Exercício 4

# %%
n=float(input('Número: ')); print('Positivo' if n>0 else ('Negativo' if n<0 else 'Zero'))

# %% [markdown]
# ## Exercício 5

# %%
n=int(input('Número: ')); print('Múltiplo de 3' if n%3==0 else 'Não é')

# %% [markdown]
# ## Exercício 6

# %%
n=int(input('Número: ')); m=int(input('Multiplo: ')); print('Sim' if n%m==0 else 'Não')

# %% [markdown]
# ## Exercício 7

# %%
n=int(input('Número: ')); print('Par' if n%2==0 else 'Ímpar')

# %% [markdown]
# ## Exercício 8

# %%
n=float(input('Número: ')); print(n/2 if n>20 else n*2)

# %% [markdown]
# ## Exercício 9

# %%
a=int(input('A: ')); b=int(input('B: ')); r=a+b; print(r*r if r>10 else r/2)

# %% [markdown]
# ## Exercício 10

# %%
n1=float(input('P1: ')); n2=float(input('P2: ')); n3=float(input('P3: ')); media=(n1*2+n2*3+n3*5)/10; print('Aprovado' if media>=6 else 'Reprovado')

# %% [markdown]
# ## Exercício 11

# %%
n1=input('Nome 1: '); p1=float(input('Peso 1: ')); n2=input('Nome 2: '); p2=float(input('Peso 2: ')); print(n1 if p1>p2 else n2)

# %% [markdown]
# ## Exercício 12

# %%
n=float(input('Número: ')); print('Dentro' if 20<=n<=90 else 'Fora')

# %% [markdown]
# ## Exercício 13

# %%
a=float(input('A: ')); b=float(input('B: ')); print('A maior' if a>b else ('B maior' if b>a else 'Iguais'))

# %% [markdown]
# ## Exercício 14

# %%
media_ap=float(input('Média aprovação: ')); nome=input('Nome: '); sexo=input('Sexo: ').upper(); n1=float(input('N1: ')); n2=float(input('N2: ')); n3=float(input('N3: ')); media=(n1+n2+n3)/3; status='aprovado' if media>=media_ap else 'reprovado'; print(f'O aluno {nome} foi {status} com média {media:.2f}')

# %% [markdown]
# # 📙 Lista 3 – Exercícios

# %% [markdown]
# ## Exercício 1

# %%
print('Hello World! '*10)

# %% [markdown]
# ## Exercício 2

# %%
for _ in range(10): print('Hello World!')

# %% [markdown]
# ## Exercício 3

# %%
for i in range(1,101): print(i)

# %% [markdown]
# ## Exercício 4

# %%
for i in range(1,101): print(f'{i}- Hello World!')

# %% [markdown]
# ## Exercício 5

# %%
for i in range(100,-1,-1): print(i)

# %% [markdown]
# ## Exercício 6

# %%
for i in range(2,1001,2): print(i)

# %% [markdown]
# ## Exercício 7

# %%
for i in range(999,-1,-2): print(i)

# %% [markdown]
# ## Exercício 8

# %%
print(sum(range(1,101)))

# %% [markdown]
# ## Exercício 9

# %%
n=int(input('Vezes: ')); [print('Hello World!') for _ in range(n)]

# %% [markdown]
# ## Exercício 10

# %%
p=input('Palavra: '); n=int(input('Vezes: ')); [print(p) for _ in range(n)]
# Out:
# Palavra: po
# Vezes: 20
# po
# po
# po
# po
# po
# po
# po
# po
# po
# po
# po
# po
# po
# po
# po
# po
# po
# po
# po
# po
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# ## Exercício 11

# %%
q=int(input('Qtd: ')); nums=[float(input('Número: ')) for _ in range(q)]; print(sum(nums), sum(nums)/q)

# %% [markdown]
# ## Exercício 12

# %%
q=int(input('Qtd: ')); nome_max=''; idade_max=-1
for _ in range(q): nome=input('Nome: '); idade=int(input('Idade: '));
 if idade>idade_max: idade_max=idade; nome_max=nome
print('Mais velho:',nome_max)

# %% [markdown]
# ## Exercício 13

# %%
q=int(input('Qtd: ')); M=[]; F=[]
for _ in range(q): s=input('Sexo: ').upper(); i=int(input('Idade: ')); (M if s=='M' else F).append(i)
print(sum(M)/len(M), sum(F)/len(F))

# %% [markdown]
# ## Exercício 14

# %%
nums=[float(input('Número: ')) for _ in range(10)]; print(max(nums), min(nums))

# %% [markdown]
# ## Exercício 15

# %%
nums=[]
while True:
 n=float(input('Número (0 para parar): '))
 if n==0: break
 nums.append(n)
nums.sort(); print(nums)
# Out:
# Número (0 para parar): 1
# Número (0 para parar): 2
# Número (0 para parar): 3
# Número (0 para parar): 2
# Número (0 para parar): 0
# [1.0, 2.0, 2.0, 3.0]

# %% [markdown]
# ## Exercício 16

# %%
idades=[]
while input('Continuar? (S/N): ').upper()=='S': idades.append(int(input('Idade: ')))
print(min(idades), max(idades))
